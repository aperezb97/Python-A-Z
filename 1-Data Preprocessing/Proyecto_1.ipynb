# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importamos el dataset

# %%
dataset = pd.read_csv('Data.csv')

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 3].values

# %% [markdown]
# Hacer reemplazo de valores por la media

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = "mean")

# %%
imputer = imputer.fit(x[:, 1:3])
x[:, 1:3] = imputer.transform(x[:, 1:3])

# %% [markdown]
# Codificar datos categoricos

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder_x = LabelEncoder()

# %%
labelencoder_x.fit_transform(x[:, 0])
# Out:
# array([0, 2, 1, 2, 1, 0, 2, 0, 1, 0])

# %%
x[:; 0] = labelencoder_x.fit_transform(x[:, 0]) #esto nos va a dar la version traudicda de como van a quedar los paises.
# Out:
#   File "<ipython-input-37-e26bdc928a56>", line 1
#     x[:; 0] = labelencoder_x.fit_transform(x[:, 0]) #esto nos va a dar la version traudicda de como van a quedar los paises.
#        ^
# SyntaxError: invalid syntax

# %%
x[:, 0] = labelencoder_x.fit_transform(x[:, 0]) #esto nos va a dar la version traudicda de como van a quedar los paises.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(
    [('one_hot_encoder', OneHotEncoder(categories='auto'), [0])],   
    remainder='passthrough'                        
)

X = np.array(ct.fit_transform(X), dtype=np.float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=43'>44</a> )
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=44'>45</a>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=45'>46</a> X = np.array(ct.fit_transform(X), dtype=np.float)
#
# NameError: name 'X' is not defined

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer(
    [('one_hot_encoder', OneHotEncoder(categories='auto'), [0])],   
    remainder='passthrough'                        
)

# %%
X = np.array(ct.fit_transform(X), dtype=np.float)

# %%
x = np.array(ct.fit_transform(x), dtype=np.float)

# %%
from sklearn import preprocessing

# %%
le_X = preprocessing.LabelEncoder()

# %%
x[:,0] = le_X.fit_transform(x[:,0])

# %% [markdown]
# Creando modelo del algoritmo, diviendo el dataset en entrenamiento y testing, para que el agoritmo sepa aprender y predcir la variable independiente, poniendo a prueba el algoritmo.

# %% [markdown]
# Diviendo el data set en conjunto de entrenamiento y conjunto de testing

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# train test split nos permite dividir el dataset en entrenamiento y test. x train es el conjunto de entrenamiento y test las variables que va a testear. Lo mismo con x e y . Siempre se usa entre un 0.2 y 0.3 ya que mientras mas variables para testear tiene el algoritmo menos tiene para entrenar, es raro usar un 0.5 y 0.5 . Test size es justamente el tamaño que vamos a testear. Random_state es el numero para reproducir el algoritmo, esta variable es aleatoria y para que no se aleatoria se usa esta variable

# %%
#la division de arriba pide de inmediato cuatro variables por lo cual las tengo que declarar ahora.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ALEPER~1\AppData\Local\Temp/ipykernel_21460/2689974272.py in <module>
#       1 #la division de arriba pide de inmediato cuatro variables por lo cual las tengo que declarar ahora.
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)
#
# NameError: name 'x' is not defined
