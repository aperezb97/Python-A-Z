# %%
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Data.csv')

# x es la variable independiente y la y la dependeinte que sera comprado.
x = df.iloc[:, :-1].values #todas las columnas menos las ultimas
y = df.iloc[:, 3].values #solo la tercer columna



#solucionar datos NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Data.csv')

# x es la variable independiente y la y la dependeinte que sera comprado.
x = df.iloc[:, :-1].values #todas las columnas menos las ultimas
y = df.iloc[:, 3].values #solo la tercer columna



#solucionar datos NaN

# %%
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df = pd.read_csv('Data.csv')

# %%
print.df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=5'>6</a> print.df
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'df'

# %%
print(df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
y = df.iloc[:, 3].values

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True, add_indicator=False);
imputer.fit(X[:, 1:3]);
X[:, 1:3]=imputer.transform(X[:, 1:3]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=16'>17</a> from sklearn.impute import SimpleImputer
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> imputer=SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True, add_indicator=False);
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer.fit(X[:, 1:3]);
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> X[:, 1:3]=imputer.transform(X[:, 1:3]);
#
# NameError: name 'np' is not defined

# %%
from sklearn.preprocessing import Imputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=16'>17</a> from sklearn.preprocessing import Imputer
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (c:\Users\Ale Perez\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
imputer = imputer.fit(X[:,1:3])
X[:, 1:3]=imputer.transform(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=16'>17</a> from sklearn.impute import SimpleImputer
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> X[:, 1:3]=imputer.transform(X[:, 1:3])
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Data.csv')
print(df)


# x es la variable independiente y la y la dependeinte que sera comprado.
x = df.iloc[:, :-1].values #todas las columnas menos las ultimas
y = df.iloc[:, 3].values #solo la tercer columna



#solucionar datos NaN
#cuando quiero solo una parte de la libreria uso from
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
imputer = imputer.fit(X[:,1:3])
X[:, 1:3]=imputer.transform(X[:, 1:3])
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#      <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=16'>17</a> from sklearn.impute import SimpleImputer
#      <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
# ---> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#      <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> X[:, 1:3]=imputer.transform(X[:, 1:3])
#      <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=20'>21</a>
#
# NameError: name 'X' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
imputer = imputer.fit(X[:,1:3])
X[:, 1:3]=imputer.transform(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> X[:, 1:3]=imputer.transform(X[:, 1:3])
#
# NameError: name 'X' is not defined

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)

# %%
imputer = imputer.fit(X[:,1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#
# NameError: name 'X' is not defined

# %%
imputer = imputer.fit(X[:,1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#
# NameError: name 'X' is not defined

# %%
import numpy as np

# %%
imputer = imputer.fit(X[:,1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = imputer.fit(X[:,1:3])
#
# NameError: name 'X' is not defined

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
imputer = imputer.fit(X[:,1:3])
X[:, 1:3]=imputer.transform(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> from sklearn.impute import SimpleImputer
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> imputer = imputer.fit(X[:,1:3])
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=20'>21</a> X[:, 1:3]=imputer.transform(X[:, 1:3])
#
# NameError: name 'X' is not defined

# %%
x = df.iloc[:, :-1].values #todas las columnas menos las ultimas
y = df.iloc[:, 3].values

# %%
y = df.iloc[:, 3].values

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
imputer = imputer.fit(X[:,1:3])
X[:, 1:3]=imputer.transform(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Programacion\GitHub\Python-A-Z\1-Data Preprocessing\Proyecto_1.py in <module>
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=17'>18</a> from sklearn.impute import SimpleImputer
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=18'>19</a> imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)
# ----> <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=19'>20</a> imputer = imputer.fit(X[:,1:3])
#       <a href='file:///f%3A/Programacion/GitHub/Python-A-Z/1-Data%20Preprocessing/Proyecto_1.py?line=20'>21</a> X[:, 1:3]=imputer.transform(X[:, 1:3])
#
# NameError: name 'X' is not defined

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean', fill_value=None, verbose=0, copy=True)

# %%
imputer = imputer.fit(x[:,1:3])
# Out:
# c:\Users\Ale Perez\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:337: FutureWarning: The 'verbose' parameter was deprecated in version 1.1 and will be removed in 1.3. A warning will always be raised upon the removal of empty columns in the future version.
#   warnings.warn(
